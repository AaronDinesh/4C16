# %% [markdown]
# This Lab 0 is made of two parts:
# * in Part I, we give a gentle introduction to Python. This is mainly a part to read an tinkle with.
# * in Part II, you will find the instructions required for the completion of two exercises that you will need to submit

# %% [markdown]
# # I - A Gentle Introduction to Python
#
# The next few cells are a gentle introduction to Python. If you are already quite familiar with Python, you can skip to section II

# %% [markdown]
# ## Python Statements
#
# * Programming language statement $\approx$ sentence
# * Building blocks with which we describe what we intend for computer
# * Simplest kind of statement is an _expression_: computes a value
# * Another common kind of statement is an _assignment_: associates a value with a name (variable)
# * Generally in Python, a statement is exactely one line (i.e. runs to end of line)

# %% [markdown]
# ## Expression Statements

# %%
5

# %%
1.23

# %%
-3 + 0.4j

# %%
"Hugh"

# %%
x # will generate an error because 'x' is not defined

# %% [markdown]
# ## Expression Statements with Operators

# %%
5 + 3

# %%
1.23 - 2 * (2 + 3/9)

# %%
-3 + 0.4j

# %%
"Hugh" + " " + 'Denman'

# %%
10 / 3

# %%
10 // 3

# %%
0.2 + 0.1 # note the binary rounding at the end

# %% [markdown]
# ## Value Types

# %%
type(3)

# %%
type(3.3)

# %%
type(3.3 + 3j)

# %%
type('hugh' + 'harry')

# %%
print(print('hugh'))

# %%
type(print('hugh'))

# %% [markdown]
# ##Assignment statements and variables

# %%
x = 3 # no need to declare variables
x + 5

# %%
eigenvalue = 2 # ... which can have pitfalls
eignvalue = eigenvalue + 1. # see typo in variable name

# %%
type(x=3)      # assignment is not an expression

# %%
x = 3    # variables may change type, or: 'python is dynamically typed'
type(x)

# %%
x = 3.3
type(x)

# %% [markdown]
# ## Statement Parsing

# %% [markdown]
# ```
# >>> x = 3↵         # A newline marks the end of statement
# >>> x = 3␣␣␣↵      # trailing spaces are OK
# 8
# >>> x +↵           # the line must make a complete statement
# SyntaxError: invalid syntax
# >>> x = (3 +
# ... 3)             # unless you use parentheses
# 4
# >>> y = 1; y + 3; y + 1↵
# 4                  # a semicolon also terminate a statement
# 2
# ```

# %% [markdown]
# ## Python functions
#
# A function definition permits the assignement of a name to a statement or a group of statements, just as variable definition permits the assigning of a name to a value.
#
# user-defined functions provide a higher-level abstraction / semantic unit. This is critical for readable, maintanable programs.

# %%
def say_stuff():        # define function
  print("some day")     # spaces at the start (typically 2 or 4)
  print("when the world is cold")
  print("I will feel a glow")
  print("just like thinking of you")
  print("and the way you look tonight") # to end function add newline (press return)

# new code that is outside of function

# %%
say_stuff()

# %% [markdown]
# ## Python functions: running from file
#
# * create and open a new file in current directory (call it 'test.py').
# * put function 'say_stuff' into this file
# * save it

# %%
# calling function say_stuff from this file:
# notice that the function is within the 'test' namespace

import test
test.say_stuff()

# %%
# note that functions can also be imported into the global namespace:

from test import say_stuff
say_stuff()

# %% [markdown]
# ## Python functions: reloading after a change
#
# If you want to test an updated version of the function, you can either exit python and restart, or reload within the session:
#
# * Make a change to the function in the 'test.py' file

# %%
import importlib              # enables reloading
test = importlib.reload(test) # actually reload
test.say_stuff()              # Run updated version

# %% [markdown]
# ## Boolean values and control flow
#
# A boolean value is either True or false.
# Booleans are used principally for `if` and `while` statements.
#
# ```python
# x = False # Boolean literal
# it_is_raining = (current_precipitation() == 'rain')
# if (it_is_raining): # using a boolean in a conditional
#   deploy_umbrella()
# else:
#   don_t_shirt()
#
# while(current_precipitation() == 'rain'):
#   stare_out_window()
# go_outside()
# ```
#
# All values can be converted to / evaluated as Boolean and used in conditionals. All values are True expect None, any number evaluating to 0, and any empty collection (including an empty string)

# %% [markdown]
# ## Compound Types
#
# Compound Types contain multiple types.

# %%
l = ['a', 3, 8.3, [4, 4]] # list
print(l[0]) # elt access by index
print(l[1:3]) # slice access by range

# %%
t = ('Hugh', 1978, ['Francis', 'Norah-Mae']) # tuple
t[0]

# %%
d = {'dog': 'mammal',
     'crocodile': 'reptile'}
d['dog']

# %% [markdown]
# The members of a compound value need not be of the same type.

# %%
## The value of a compound type is its location

# %%
def add_one(x):
  x  = x + 1

# %%
a = 2; add_one(a); print(a)

# %%
def add_one_to_first(x):
  x[0] = x[0] + 1

# %%
l = [2, 'hugh']; add_one_to_first(l); print(l)

# %%
add_one(l); # throws an error

# %%
add_one_to_first(a)  # throws an error

# %% [markdown]
# ## Loops and Lists
#
# Transforming a list:

# %%
my_list = [5,6,7,8,9,10]

# %%
my_list = list(range(5, 11)) # (list contents identical

# %%
new_list = []
for i in range(len(my_list)):        # traditional
  new_list.append(my_list[i] * 2)

# %%
new_list = [2*x for x in my_list]    # More Pythonic

# %% [markdown]
# Summing (reducing) a list:

# %%
my_sum = 0
for i in range(len(my_list)):        # traditional
  my_sum = = my_sum + my_list[i]

# %%
my_sum = 0
for e in my_list:                    # More Pythonic
  my_sum = my_sum + e

# %%
my_sum = sum(my_list)                # (as it happens there is a built-in 'sum' function)

# %% [markdown]
# ## Modules
#
# Python comes with a large library of useful functions. These are organised into _modules_.

# %%
import math

# %%
print(math.sqrt(2))

# %%
[0.1] * 10

# %%
print(sum([0.1]*10))

# %%
from math import fsum

# %%
print(fsum([0.1]*10))

# %% [markdown]
# ## Common and Useful Modules
#
# Built-in modules (the Python Standard Library):
# * Interacting with host operating system and computer
# * Internet communications
# * Reading and writing simple sound and image format
#
# Third-party modules:
# * More complex sound and image formats
# * Fast numerical processing and scientific computations
# * Graphing and plotting
#
# A Python programmer will typically organise their own code into several modules when writing larger programs.

# %% [markdown]
# ## Not Covered
#
# * Other types (sets, fractions, ...)
# * Classes / object orientation
# * Error handling & exceptions
# * File I/O

# %% [markdown]
# ## Going Further
#
# When looking for Python help online, be sure to use the search term python3, as several important things have changed from the previous, still very widespread, version 2.
#
# * print is a function in v3
# * xrange is now a range in v3

# %% [markdown]
# #II - Excercises

# %% [markdown]
# ## Mounting your Google Drive
#
# To work on the exercise, you'll need to access a few files in your git repository: namely ex_1.py and ex_2.py. At the moment, these files only exit on your copy of the repository that is on your google drive.
#
# The first step is thus to mount your Google Drive on your colab machine. Remember that Colab is basically running a virtual machine for this notebook, and this machine has currently no access to your other files.

# %%
# running this cell will mount your google drive
# onto the /content/drive folder on your notebook machine.
# this will require you to authorise colab to mount your drive.
# be careful, from here on, your personal gdrive is mounted, along
# with your personal data. So, just be careful and don't start deleting files :-)

from google.colab import drive
drive.mount('/content/drive/')

# %%
# we can now change working directory to be on lab-00

# %cd /content/drive/MyDrive/4c16-labs/code/lab-00

# %% [markdown]
# # Exercise 1
#
# * open 'ex_1.py' (exercise 1)
#
# The first exercise has three parts. Read the text to get a feel for the problems.

# %%
# we can run this code.

# %run ex_1.py

# %% [markdown]
# This will try to run the code appearing in 'ex_1.py' under
# ```
# if __name__ == "__main__":
# ```
# This will get you errors at first as the lab has not been completed.
#
# Work through the three parts of exercise 1. Save the file and run the cell again as you complete each part, to check your progress

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **TODO**:
# * Uncomment and fix up the 'safe_div' function (indents, colons).
# * Fix the error in the function 'compute_sum'
# * Add a new function 'compute_product' to compute the product of three numbers

# %% [markdown]
# ## Submit Lab for assessment
#
# Whenever you want, you can go back to the 4c16-git-workflow.ipynb notebook:
# * commit and push your changes
# * submit your lab

# %% [markdown]
# ## Exercise 2
#
# Open the ex_2.py file and have a look. The task here is to flesh out an implementation of Netwon's method (Newton Rhapson) for finding a root of a function $f(x)$ (a value $\hat{x}$ such that $f(\hat{x})=0$).
# The method is as follows:
#
# $$
# x_{n+1} = x_{n} - \frac{f(x_n)}{f'(x_n)}
# $$
#
# **TODO**:
# * Fix the indent
# * Use if derivative == 0 to check if the search has to be abandoned.
# * Use the abs() function to check the size of the update.
# * Use if i > 100: to check the number of iterations
#
# **TO CHECK**:
# use git-workflow notebook to commit and submit lab for assessment.

# %% [markdown]
# # ⚠ Remember: your code WILL be lost if you don't commit and push!!!
